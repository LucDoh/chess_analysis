# %% [markdown]
# ### Picking up failed puzzles
#     1) Pull tactics from chess.com
#     2) Store puzzle rating, link, time it took, if succeded/failed.

# %% [markdown]
# As far as I can tell, there is no chess.com API for pulling puzzles like there is for games. Should be able to parse it ourselves in some capacity from the web site.

# %%
# Example: https://www.chess.com/stats/puzzles/luc777

# %%
import html
import pandas as pd
import numpy as np
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service

def instantiate_webdriver():
    # Set path Selenium
    CHROMEDRIVER_PATH = '/usr/local/bin/chromedriver'
    s = Service(CHROMEDRIVER_PATH)
    WINDOW_SIZE = "1920,1080"

    # Create chrome webdriver
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--window-size=%s" % WINDOW_SIZE)
    chrome_options.add_argument('--no-sandbox')
    return webdriver.Chrome(executable_path=CHROMEDRIVER_PATH, options=chrome_options)

# %%
def navigate_to_last_opened(driver):
    """Given a driver, navigate to last opened window (e.g. from a click())."""
    time.sleep(2)
    window_after = driver.window_handles[-1]
    driver.switch_to.window(window_after)
    print(driver.current_url)
    
def safe_click(driver, element):
    """Scrolls into view before clicking an element."""
    driver.execute_script("arguments[0].scrollIntoView();", element)
    element.click()
    
    
def safe_click2(driver, element):
    """Scrolls into view before clicking an element."""
    driver.execute_script("arguments[0].scrollIntoView();", element)
    driver.execute_script("arguments[0].click();", element) 


def get_user_puzzles(user, driver):
    """Find out which puzzles they recently attempted and navigate driver to that page."""
    url = f"https://www.chess.com/stats/puzzles/{user}"
    page = driver.get(url)
    time.sleep(2)
    return pd.read_html(driver.page_source)[0]

# %%
driver = instantiate_webdriver()

# %%
get_user_puzzles('Luc777', driver).head()
# Out:
#            Date       ID  Rating Moves Target Avg Time My Time My Time.1  \
# 0  Apr 24, 2022  1223479    2061   9/9   0:51     0:37    0:56       99%
# 1  Apr 24, 2022  1128162    2020   4/6   0:35     1:52    0:47       64%
# 2  Apr 24, 2022  1310551    2274   2/4   0:38     1:21    1:21       44%
# 3  Apr 24, 2022  1669636    2207   3/3   0:28     0:55    0:31       99%
# 4  Apr 24, 2022  1835548    2281   4/4   0:34     1:28    2:42       70%
#
#    Outcome  Outcome.1
# 0       10       2439
# 1        5       2429
# 2       -4       2424
# 3       11       2428
# 4        5       2417

# %% [markdown]
# ### Navigate to tab-rush

# %%
def navigate_to_puzzle_rush_table(user, driver):
    # Navigate to their puzzles page
    url = f"https://www.chess.com/stats/puzzles/{user}"
    page = driver.get(url)
    time.sleep(2)
    # Click the rush tab
    element = driver.find_element_by_id("tab-rush")
    time.sleep(2)
    driver.execute_script("arguments[0].scrollIntoView();", element)
    element.click()

# %%
def get_user_puzzle_rush_scores(user, driver):
    navigate_to_puzzle_rush_table(user, driver)
    return pd.read_html(driver.page_source)[0]

# %%
df_rush = get_user_puzzle_rush_scores("Luc777", driver)
df_rush.head(3)
# Out:
#            Date   Time  Result  Streak  Highest Solved Time/Puzzle
# 0  Apr 24, 2022  5 min      24      17            1450        0:11
# 1  Apr 24, 2022  5 min      22      21            1276        0:13
# 2  Apr 17, 2022  5 min      22      22            1246        0:12

# %% [markdown]
# ### Now hone in on specific puzzles missed in their rush
# This assumes the driver is on a user's puzzle page + has clicked the "rush" tab.

# %% [markdown]
# Navigate to the page describing the most recent rush

# %%
from bs4 import BeautifulSoup
def element_to_failed_puzzles_dataset(element, driver):
    """ Given an element pointing to a specific puzzle rush, generate an array describing 
    failed puzzles.
    """
    # Navigate to specific puzzle rush page
    element.click()
    navigate_to_last_opened(driver)
    source_rush = driver.current_url
    source_rush_window = driver.window_handles[-1]
    
    # Get failed puzzles
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    puzzle_divs = soup.find_all("div", {"class": "streak-indicator-streak streak-indicator-incorrect streak-indicator-link"})
    puzzle_ratings = [puzzle_div.text.strip() for puzzle_div in puzzle_divs]
    failure_links = driver.find_elements_by_class_name('streak-indicator-incorrect')
    
    # Iterate through failed puzzles to create dataset
    failed_puzzle_dataset = []
    for puzzle_rating, failure_element in zip(puzzle_ratings, failure_links):
        # Navigate to each failed puzzle to get link (hacky)
        time.sleep(3)
        print(failure_element)
        #safe_click(driver, failure_element)
        safe_click2(driver, failure_element)
        navigate_to_last_opened(driver)
        failed_puzzle_dataset.append((puzzle_rating, driver.current_url, source_rush))
        # Switch back to source
        time.sleep(1)
        driver.switch_to.window(source_rush_window)
    return failed_puzzle_dataset

# %%
def get_failed_puzzles(driver, user, limit=10):
    """Generate a list of failed puzzles from Puzzle Rush."""
    navigate_to_puzzle_rush_table(user, driver)
    # Elements of rows (tr), where each is a separate puzzle rush. 
    elmnts = driver.find_elements_by_xpath("//table/tbody/tr")
    failed_puzzles = []
    for i in range(min(len(elmnts), 10)):
        navigate_to_puzzle_rush_table(user, driver)
        elmnts = driver.find_elements_by_xpath("//table/tbody/tr")
        failed_puzzles.extend(element_to_failed_puzzles_dataset(elmnts[i], driver))
    return failed_puzzles

# %%
driver = instantiate_webdriver()
failed_puzzles_data = get_failed_puzzles(driver, "Luc777")
# Out:
# https://www.chess.com/puzzles/rush/luc777/6Q6WA
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="85344635-8e7c-4ae9-80bc-ffb3cb53255d")>
# https://www.chess.com/puzzles/problem/621340
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="c27c3f62-7bd3-4d2b-888e-515b6822aa5a")>
# https://www.chess.com/puzzles/problem/1150640
# https://www.chess.com/puzzles/rush/luc777/4XoRuY
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="9b32d7c3-b244-40b5-bbee-951b7710c9e8")>
# https://www.chess.com/puzzles/problem/1644026
# https://www.chess.com/puzzles/rush/luc777/Q9iN2
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="69e8d6bc-c06d-47a5-9f91-7cb152e3bcbe")>
# https://www.chess.com/puzzles/problem/1198420
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="2c327a47-1182-4e9b-93e5-532ef26ba6cf")>
# https://www.chess.com/puzzles/problem/1145272
# https://www.chess.com/puzzles/rush/luc777/3zgmr6
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="faa202c2-7612-425a-8313-eec31b279257")>
# https://www.chess.com/puzzles/problem/1477156
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="2c05bc6d-5da3-4673-9869-3b6e33f417d6")>
# https://www.chess.com/puzzles/problem/697840
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="8d7b4b1f-3f26-400c-b40c-2b22eee7e482")>
# https://www.chess.com/puzzles/problem/1147522
# https://www.chess.com/puzzles/rush/luc777/5EkA9U
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="92cfb9a0-0f62-4c5d-a380-f8224c1b4928")>
# https://www.chess.com/puzzles/problem/1152416
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="cfd02227-5233-40df-91c2-edc357ead29f")>
# https://www.chess.com/puzzles/problem/615876
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="5439a814-5be6-4206-942d-661bb7db6780")>
# https://www.chess.com/puzzles/problem/1259803
# https://www.chess.com/puzzles/rush/luc777/78xQrS
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="b0b65dab-e8b2-4650-8611-767aaa685e5b")>
# https://www.chess.com/puzzles/problem/1146992
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="6021736f-e466-4d8b-b37b-db8e89afd269")>
# https://www.chess.com/puzzles/problem/1247977
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="35b8c699-2018-41e0-b675-571aefce1dd9")>
# https://www.chess.com/puzzles/problem/1140978
# https://www.chess.com/puzzles/rush/luc777/6fFX2N
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="3a8609cd-7ea1-4295-a10f-5e901ca16987")>
# https://www.chess.com/puzzles/problem/1073678
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="535cb371-3e61-4d32-b816-3ba33f6ea2e2")>
# https://www.chess.com/puzzles/problem/624052
# https://www.chess.com/puzzles/rush/luc777/5KSxE2
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="11c3137f-8861-470a-b157-b5cff4b6f23e")>
# https://www.chess.com/puzzles/problem/1013274
# https://www.chess.com/puzzles/rush/luc777/7Y4NvS
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="c887519b-bdf5-4118-9594-313d917f40b4")>
# https://www.chess.com/puzzles/problem/1050856
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="82b0da80-f717-4ec1-ba81-0cfea8782f36")>
# https://www.chess.com/puzzles/problem/520356
# https://www.chess.com/puzzles/rush/luc777/68X4RU
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="f0b43ce5-4642-475b-a550-2a52ddbea4b8")>
# https://www.chess.com/puzzles/problem/1382626
# https://www.chess.com/puzzles/rush/luc777/3ncL5U
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="e80ce292-ae3b-4d0f-b437-0282f685b8ad")>
# https://www.chess.com/puzzles/problem/1523824
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="84df2771-cdc0-46b0-8c01-fe930f37f284")>
# https://www.chess.com/puzzles/problem/579226
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="b1720c2f-5656-4cc4-895d-e3d355b8d43e")>
# https://www.chess.com/puzzles/problem/1471692
# https://www.chess.com/puzzles/rush/luc777/2P2zgv
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="1bea3d55-b310-484f-a63d-d455ec502b25")>
# https://www.chess.com/puzzles/problem/1106240
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="bf9d2045-176f-4bb3-b1e6-d4e9abb11b1b")>
# https://www.chess.com/puzzles/problem/1162196
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="a2cc04cd-00bc-4054-a780-bfadbbc4a3d5")>
# https://www.chess.com/puzzles/problem/1502122
# https://www.chess.com/puzzles/rush/luc777/5atqXc
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="7d180cbd-1474-42e8-94f1-e36802bca6d0")>
# https://www.chess.com/puzzles/problem/594404
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="2ca5dfd2-7172-44fa-b17e-a86fd9db140e")>
# https://www.chess.com/puzzles/problem/1106204
# https://www.chess.com/puzzles/rush/luc777/7H7Wwx
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="36ad879a-0c0d-457a-9a5f-bf7adbf1bf8a")>
# https://www.chess.com/puzzles/problem/1031434
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="6ccdee6e-d077-4a0b-bdd1-19ea4b9281c7")>
# https://www.chess.com/puzzles/problem/1145192
# https://www.chess.com/puzzles/rush/luc777/2b4njg
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="5fca5a15-e4c6-472f-857e-014149d65254")>
# https://www.chess.com/puzzles/problem/989784
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="ba20b63d-2cc2-4f2e-b2cd-8aa5737e13ce")>
# https://www.chess.com/puzzles/problem/1039272
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="c73e7794-f3ea-4743-b1e2-1914b888e06a")>
# https://www.chess.com/puzzles/problem/1671976
# https://www.chess.com/puzzles/rush/luc777/kK4i2
# <selenium.webdriver.remote.webelement.WebElement (session="35e38053ae690ecccdc18eb94572f6c9", element="b1889164-f3a1-4c96-a94c-fd3e7ba6f347")>
# https://www.chess.com/puzzles/problem/1180424
# https://www.chess.com/puzzles/rush/luc777/2qWHbU
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /tmp/ipykernel_4419/3993051854.py in <module>
#       1 driver = instantiate_webdriver()
# ----> 2 failed_puzzles_data = get_failed_puzzles(driver, "Luc777")
#
# /tmp/ipykernel_4419/3307385817.py in get_failed_puzzles(driver, user)
#       8         navigate_to_puzzle_rush_table(user, driver)
#       9         elmnts = driver.find_elements_by_xpath("//table/tbody/tr")
# ---> 10         failed_puzzles.extend(element_to_failed_puzzles_dataset(elmnts[i], driver))
#      11     return failed_puzzles
#
# /tmp/ipykernel_4419/4278053769.py in element_to_failed_puzzles_dataset(element, driver)
#      11
#      12     # Get failed puzzles
# ---> 13     soup = BeautifulSoup(driver.page_source, 'html.parser')
#      14     puzzle_divs = soup.find_all("div", {"class": "streak-indicator-streak streak-indicator-incorrect streak-indicator-link"})
#      15     puzzle_ratings = [puzzle_div.text.strip() for puzzle_div in puzzle_divs]
#
# ~/anaconda3/envs/py38t/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~/anaconda3/envs/py38t/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/envs/py38t/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: session deleted because of page crash
# from unknown error: cannot determine loading status
# from tab crashed
#   (Session info: headless chrome=99.0.4844.84)

# %% [markdown]
# Moved this code to chess_analytics/puzzle_fetcher.py.
